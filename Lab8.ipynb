# %% [markdown]
# <a href="https://colab.research.google.com/github/saiprasad0905/Visual_Recognition_and_Scene_Understanding/blob/main/Lab8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 20.8 MB/s eta 0:00:00
# ...

# %%
# Install library (run once in Colab)
# !pip install ultralytics

# Import libraries
from ultralytics import YOLO
import cv2
from google.colab.patches import cv2_imshow

# Load pretrained YOLOv8 Nano model
model = YOLO('yolov8n.pt')

# Run detection on image
results = model('street.webp', conf=0.5)

# Process detection results
for result in results:
    boxes = result.boxes

    for box in boxes:
        x1, y1, x2, y2 = box.xyxy[0].tolist()
        conf = box.conf[0].item()
        cls_id = int(box.cls[0].item())
        cls_name = model.names[cls_id]

        print(f'{cls_name}: {conf:.2f} at [{x1:.0f}, {y1:.0f}, {x2:.0f}, {y2:.0f}]')

# Show image with bounding boxes
annotated = results[0].plot()
cv2_imshow(annotated)
# Out:
# ...
#
# image 1/1 /content/street.webp: 480x640 7 cars, 356.5ms
# Speed: 12.7ms preprocess, 356.5ms inference, 35.8ms postprocess per image at shape (1, 3, 480, 640)
# car: 0.85 at [218, 114, 276, 160]
# car: 0.80 at [284, 25, 311, 46]
# car: 0.77 at [154, 140, 231, 220]
# car: 0.69 at [355, 1, 376, 14]
# car: 0.62 at [301, 7, 325, 29]
# car: 0.57 at [256, 42, 289, 68]
# car: 0.53 at [236, 58, 277, 94]
# <PIL.Image.Image image mode=RGB size=389x280>
